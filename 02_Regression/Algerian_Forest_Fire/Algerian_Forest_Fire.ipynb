# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## dataset load

df=pd.read_csv("/content/Algerian_forest_fires_dataset_UPDATE.csv",header=1)
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
df.shape
# Out:
# (246, 14)

# %%
df.columns=df.columns.str.strip()

# %%
df["Classes"].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# Classes            1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df["Region"]=1

# %%
df.head()
df.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC  DMC    DC  ISI   BUI  FWI  \
# 241  26    09  2012          30  65  14    0  85.4   16  44.5  4.5  16.9  6.5
# 242  27    09  2012          28  87  15  4.4  41.1  6.5     8  0.1   6.2    0
# 243  28    09  2012          27  87  29  0.5  45.9  3.5   7.9  0.4   3.4  0.2
# 244  29    09  2012          24  54  18  0.1  79.7  4.3  15.2  1.7   5.1  0.7
# 245  30    09  2012          24  64  15  0.2  67.3  3.8  16.5  1.2   4.8  0.5
#
#           Classes  Region
# 241       fire          1
# 242   not fire          1
# 243   not fire          1
# 244   not fire          1
# 245  not fire           1

# %%
df["Region"].iloc[:122]=1
df["Region"].iloc[122:]=0
# Out:
# <ipython-input-75-6178a7ce3c8d>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["Region"].iloc[:122]=1
# <ipython-input-75-6178a7ce3c8d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Region"].iloc[:122]=1
# <ipython-input-75-6178a7ce3c8d>:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["Region"].iloc[122:]=0
# <ipython-input-75-6178a7ce3c8d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Region"].iloc[122:]=0

# %%
df.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC  DMC    DC  ISI   BUI  FWI  \
# 241  26    09  2012          30  65  14    0  85.4   16  44.5  4.5  16.9  6.5
# 242  27    09  2012          28  87  15  4.4  41.1  6.5     8  0.1   6.2    0
# 243  28    09  2012          27  87  29  0.5  45.9  3.5   7.9  0.4   3.4  0.2
# 244  29    09  2012          24  54  18  0.1  79.7  4.3  15.2  1.7   5.1  0.7
# 245  30    09  2012          24  64  15  0.2  67.3  3.8  16.5  1.2   4.8  0.5
#
#           Classes  Region
# 241       fire          0
# 242   not fire          0
# 243   not fire          0
# 244   not fire          0
# 245  not fire           0

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          1
# 1  not fire          1
# 2  not fire          1
# 3  not fire          1
# 4  not fire          1

# %%
df.iloc[122:124]
# Out:
#                                day  month  year  Temperature   RH   Ws   Rain  \
# 122  Sidi-Bel Abbes Region Dataset    NaN   NaN          NaN  NaN  NaN    NaN
# 123                            day  month  year  Temperature   RH   Ws  Rain
#
#      FFMC  DMC   DC  ISI  BUI  FWI    Classes  Region
# 122   NaN  NaN  NaN  NaN  NaN  NaN        NaN       0
# 123  FFMC  DMC   DC  ISI  BUI  FWI  Classes         0

# %%
df.iloc[121]
# Out:
# day                     30
# month                   09
# year                  2012
# Temperature             25
# RH                      78
# Ws                      14
# Rain                   1.4
# FFMC                    45
# DMC                    1.9
# DC                     7.5
# ISI                    0.2
# BUI                    2.4
# FWI                    0.1
# Classes        not fire
# Region                   1
# Name: 121, dtype: object

# %%
# df.drop(df.loc[122],axis=1)

# %%
df.shape
# Out:
# (246, 15)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          1
# 1  not fire          1
# 2  not fire          1
# 3  not fire          1
# 4  not fire          1

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
# RH             1
# Ws             1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
df[df["Classes"].isnull()]
# Out:
#                                day month  year Temperature   RH   Ws Rain  \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN  NaN
# 167                             14    07  2012          37   37   18  0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes  Region
# 122   NaN   NaN     NaN   NaN   NaN      NaN     NaN       0
# 167  88.9  12.9  14.6 9  12.5  10.4  fire        NaN       0

# %%
df.drop(122,inplace=True)

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# Region         0
# dtype: int64

# %%
df.shape
# Out:
# (245, 15)

# %%
np.where(df["Classes"]=="nan")
# Out:
# (array([], dtype=int64),)

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# Region         0
# dtype: int64

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          1
# 1  not fire          1
# 2  not fire          1
# 3  not fire          1
# 4  not fire          1

# %%
df.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC  DMC    DC  ISI   BUI  FWI  \
# 241  26    09  2012          30  65  14    0  85.4   16  44.5  4.5  16.9  6.5
# 242  27    09  2012          28  87  15  4.4  41.1  6.5     8  0.1   6.2    0
# 243  28    09  2012          27  87  29  0.5  45.9  3.5   7.9  0.4   3.4  0.2
# 244  29    09  2012          24  54  18  0.1  79.7  4.3  15.2  1.7   5.1  0.7
# 245  30    09  2012          24  64  15  0.2  67.3  3.8  16.5  1.2   4.8  0.5
#
#           Classes  Region
# 241       fire          0
# 242   not fire          0
# 243   not fire          0
# 244   not fire          0
# 245  not fire           0

# %%
df.iloc[122]
# Out:
# day                    day
# month                month
# year                  year
# Temperature    Temperature
# RH                      RH
# Ws                      Ws
# Rain                 Rain
# FFMC                  FFMC
# DMC                    DMC
# DC                      DC
# ISI                    ISI
# BUI                    BUI
# FWI                    FWI
# Classes          Classes
# Region                   0
# Name: 123, dtype: object

# %%
df.dropna().reset_index(drop=True)
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI       Classes  Region
# 0    0.5   not fire          1
# 1    0.4   not fire          1
# 2    0.1   not fire          1
# 3      0   not fire          1
# 4    0.5   not fire          1
# ..   ...           ...     ...
# 239  6.5       fire          0
# 240    0   not fire          0
# 241  0.2   not fire          0
# 242  0.7   not fire          0
# 243  0.5  not fire           0
#
# [244 rows x 15 columns]

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          1
# 1  not fire          1
# 2  not fire          1
# 3  not fire          1
# 4  not fire          1

# %%
df.shape
# Out:
# (245, 15)

# %%
df.iloc[122]
# Out:
# day                    day
# month                month
# year                  year
# Temperature    Temperature
# RH                      RH
# Ws                      Ws
# Rain                 Rain
# FFMC                  FFMC
# DMC                    DMC
# DC                      DC
# ISI                    ISI
# BUI                    BUI
# FWI                    FWI
# Classes          Classes
# Region                   0
# Name: 123, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          245 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       245 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 30.6+ KB

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# Region         0
# dtype: int64

# %%
df=df.dropna().reset_index(drop=True)

# %%
df=df.drop([122]).reset_index(drop=True)

# %%
df.shape
# Out:
# (243, 15)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          1
# 1  not fire          1
# 2  not fire          1
# 3  not fire          1
# 4  not fire          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 28.6+ KB

# %%
df=df.drop(["day","month","year"], axis=1)
df.head()
# Out:
#   Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4  not fire
# 2          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0  not fire
# 4          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.columns
# Out:
# Index(['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
#        'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.Classes.value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df["Classes"]=df["Classes"].str.strip()
df.Classes.value_counts()
# Out:
# Classes
# fire        137
# not fire    106
# Name: count, dtype: int64

# %%
df["Classes"]= df["Classes"].apply(lambda x: 1 if x=="fire" else 0)
df.Classes.value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5        0       1
# 1          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4        0       1
# 2          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       1
# 3          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0        0       1
# 4          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5        0       1

# %%
sns.pairplot(df)

# %%
sns.barplot(df)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  243 non-null    object
#  1   RH           243 non-null    object
#  2   Ws           243 non-null    object
#  3   Rain         243 non-null    object
#  4   FFMC         243 non-null    object
#  5   DMC          243 non-null    object
#  6   DC           243 non-null    object
#  7   ISI          243 non-null    object
#  8   BUI          243 non-null    object
#  9   FWI          243 non-null    object
#  10  Classes      243 non-null    int64
#  11  Region       243 non-null    int64
# dtypes: int64(2), object(10)
# memory usage: 22.9+ KB

# %%
df[["RH","Ws"]]= df[["RH","Ws"]].astype(int)

# %%
df["Classes"]=df["Classes"].astype(object)

# %%
objects=[feature for feature in df.columns if df[feature].dtype=="O"]
print(objects)
# Out:
# ['Temperature', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes']

# %%
for i in objects:
  if i!="Classes":
    df[i]=df[i].astype(float)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  243 non-null    float64
#  1   RH           243 non-null    int64
#  2   Ws           243 non-null    int64
#  3   Rain         243 non-null    float64
#  4   FFMC         243 non-null    float64
#  5   DMC          243 non-null    float64
#  6   DC           243 non-null    float64
#  7   ISI          243 non-null    float64
#  8   BUI          243 non-null    float64
#  9   FWI          243 non-null    float64
#  10  Classes      243 non-null    object
#  11  Region       243 non-null    int64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 22.9+ KB

# %%
df.Classes.value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
# plt.style.use('seaborn')
# df.hist(bins=50,figsize=(20,15))
# plt.show()

# %%
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
df.Classes.value_counts(normalize=True)
# Out:
# Classes
# 1    0.563786
# 0    0.436214
# Name: proportion, dtype: float64

# %%
perc=df.Classes.value_counts(normalize=True)*100

# %%
labels=["Fire","Not Fire"]
plt.figure(figsize=(10,5))
plt.pie(perc,labels=labels,autopct='%1.1f%%')
plt.title("PIE chart of the Class")
plt.show()

# %%
df.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# Region         -0.269555  0.402682  0.181160  0.040013 -0.222241 -0.192089
#
#                    DC       ISI       BUI       FWI   Classes    Region
# Temperature  0.376284  0.603871  0.459789  0.566670  0.516015 -0.269555
# RH          -0.226941 -0.686667 -0.353841 -0.580957 -0.432161  0.402682
# Ws           0.079135  0.008532  0.031438  0.032368 -0.069964  0.181160
# Rain        -0.298023 -0.347484 -0.299852 -0.324422 -0.379097  0.040013
# FFMC         0.507397  0.740007  0.592011  0.691132  0.769492 -0.222241
# DMC          0.875925  0.680454  0.982248  0.875864  0.585658 -0.192089
# DC           1.000000  0.508643  0.941988  0.739521  0.511123  0.078734
# ISI          0.508643  1.000000  0.644093  0.922895  0.735197 -0.263197
# BUI          0.941988  0.644093  1.000000  0.857973  0.586639 -0.089408
# FWI          0.739521  0.922895  0.857973  1.000000  0.719216 -0.197102
# Classes      0.511123  0.735197  0.586639  0.719216  1.000000 -0.162347
# Region       0.078734 -0.263197 -0.089408 -0.197102 -0.162347  1.000000

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df_temp=df.loc[df["Region"]==1]
plt.subplots(figsize=(13,6))
# sns.set_style("Whitegrid")
sns.countplot(x="Temperature", hue="Classes", data=df)
# Out:
# <Axes: xlabel='Temperature', ylabel='count'>

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI Classes  Region
# 0         29.0  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5       0       1
# 1         29.0  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4       0       1
# 2         26.0  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1       0       1
# 3         25.0  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0       0       1
# 4         27.0  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5       0       1

# %%
X=df.drop("FWI", axis=1)
y=df["FWI"]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=7)

# %%
### Check for multi collinearity

X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.647988 -0.301362 -0.343158  0.675551  0.476795
# RH             -0.647988  1.000000  0.252674  0.222883 -0.639457 -0.393571
# Ws             -0.301362  0.252674  1.000000  0.181644 -0.165632  0.026453
# Rain           -0.343158  0.222883  0.181644  1.000000 -0.552412 -0.296610
# FFMC            0.675551 -0.639457 -0.165632 -0.552412  1.000000  0.617710
# DMC             0.476795 -0.393571  0.026453 -0.296610  0.617710  1.000000
# DC              0.344483 -0.185483  0.105214 -0.299761  0.483345  0.849413
# ISI             0.599388 -0.679011  0.025977 -0.342339  0.732416  0.671200
# BUI             0.442129 -0.328502  0.058146 -0.304930  0.591021  0.980755
# Classes         0.488487 -0.403874 -0.032854 -0.372426  0.758780  0.610127
# Region         -0.249030  0.364172  0.220431  0.032196 -0.214416 -0.178767
#
#                    DC       ISI       BUI   Classes    Region
# Temperature  0.344483  0.599388  0.442129  0.488487 -0.249030
# RH          -0.185483 -0.679011 -0.328502 -0.403874  0.364172
# Ws           0.105214  0.025977  0.058146 -0.032854  0.220431
# Rain        -0.299761 -0.342339 -0.304930 -0.372426  0.032196
# FFMC         0.483345  0.732416  0.591021  0.758780 -0.214416
# DMC          0.849413  0.671200  0.980755  0.610127 -0.178767
# DC           1.000000  0.438356  0.933643  0.502631  0.117500
# ISI          0.438356  1.000000  0.607050  0.730107 -0.281127
# BUI          0.933643  0.607050  1.000000  0.591869 -0.070364
# Classes      0.502631  0.730107  0.591869  1.000000 -0.183832
# Region       0.117500 -0.281127 -0.070364 -0.183832  1.000000

# %%
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <Axes: >

# %%
def check_collinearity(data,threshold):
  col=set()
  mat=data.corr()
  for i in range(len(data.columns)):
    for j in range(i):
      if abs(mat.iloc[i,j])>threshold:
        col_m=mat.columns[i]
        col.add(col_m)
  return col

# %%
corr_feat=check_collinearity(X_train,0.80)

# %%
X_train.drop(corr_feat,axis=1,inplace=True)
X_test.drop(corr_feat,axis=1,inplace=True)
X_train.shape, X_test.shape
# Out:
# ((170, 9), (73, 9))

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
X_train[:10]
# Out:
# array([[ 1.01584483, -2.15618365,  0.98186478, -0.38871446,  1.13824611,
#          2.26820908,  3.25790417,  0.90992142, -0.94280904],
#        [-0.09116556, -0.95895593, -0.82069475, -0.24537073,  0.14088739,
#          0.37216011, -0.59545611, -1.098996  ,  1.06066017],
#        [ 0.73909223,  0.10524649, -0.46018284, -0.24537073, -0.0942043 ,
#         -0.76368054, -0.71365734, -1.098996  ,  1.06066017],
#        [-0.09116556, -0.49336737, -1.54171856, -0.14980825, -0.30080004,
#         -0.56692075, -0.83185858, -1.098996  ,  1.06066017],
#        [-1.19817595,  1.30247421, -0.09967094, -0.38871446,  0.47571496,
#         -0.14657027, -0.09901092,  0.90992142, -0.94280904],
#        [-0.92142336,  1.83457542, -0.82069475, -0.05424576, -2.97942058,
#         -1.12142563, -1.11554154, -1.098996  ,  1.06066017],
#        [-0.64467076,  0.17175914, -0.46018284, -0.38871446,  0.10526744,
#         -0.80839868, -0.59545611, -1.098996  , -0.94280904],
#        [-0.09116556,  0.770373  , -0.09967094, -0.38871446,  0.61819478,
#          1.11448117,  0.20831229,  0.90992142,  1.06066017],
#        [ 0.18558704,  0.17175914, -0.82069475, -0.38871446,  0.78204657,
#          1.06081941,  0.562916  ,  0.90992142, -0.94280904],
#        [ 0.73909223,  0.17175914,  0.98186478, -0.29315198,  0.14801139,
#         -0.40593546, -0.45361462, -1.098996  ,  1.06066017]])

# %%
X_test[:10]
# Out:
# array([[ 0.90468795,  0.3190952 ,  1.06615112, -0.36747587,  0.71164092,
#          0.69256582,  1.01551315,  0.81184414,  0.85912469],
#        [-1.0377303 , -0.88454355,  0.35538371,  0.37293729, -0.41828367,
#         -0.54435171, -0.83652983, -1.23176352, -1.16397539],
#        [-1.87019527,  1.80594307, -1.06615112,  1.0563956 , -3.27986784,
#         -0.97931172, -1.2170866 , -1.23176352,  0.85912469],
#        [ 2.01464124, -2.15898458,  0.35538371, -0.36747587,  1.07268192,
#          0.09449581,  3.1466311 ,  0.81184414, -1.16397539],
#        [-0.76024198,  1.66433851,  0.71076741, -0.36747587,  0.15670754,
#         -0.26570545, -0.50671395, -1.23176352, -1.16397539],
#        [ 0.90468795,  0.3190952 ,  0.        , -0.36747587,  0.51106259,
#         -0.38803795,  0.02606553,  0.81184414, -1.16397539],
#        [-1.87019527,  1.027118  , -0.35538371,  1.79680876, -2.34383564,
#         -0.98610797, -1.19171615, -1.23176352,  0.85912469],
#        [ 0.62719963,  0.03588609,  0.        , -0.36747587,  0.78518631,
#          2.34405461,  0.63495638,  0.81184414,  0.85912469],
#        [-1.59270694,  1.16872256,  0.        ,  0.65771159, -2.02291031,
#         -0.87057171, -1.14097525, -1.23176352,  0.85912469],
#        [ 0.34971131,  0.46069976,  0.35538371, -0.36747587,  0.51774854,
#          0.18964331,  0.10217689,  0.81184414,  0.85912469]])

# %%
sns.boxplot(X_train)
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()

model.fit(X_train,y_train)

y_pred=model.predict(X_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R2: {r2}")
# Out:
# MAE: 1.0751816008553834
# MSE: 2.56925813010977
# RMSE: 1.6028905546261636
# R2: 0.960339508663516

# %%
X_train.size
# Out:
# 1530

# %%
y_train.size
# Out:
# 170

# %%
X_test.size
# Out:
# 657

# %%
y_test.size
# Out:
# 73

# %%
plt.scatter(y_test,y_pred)

# %%
from sklearn.linear_model import LinearRegression, Lasso

model_L=Lasso()

model_L.fit(X_train,y_train)

y_pred=model_L.predict(X_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R2: {r2}")
# Out:
# MAE: 1.611982420812732
# MSE: 6.22330508502482
# RMSE: 2.494655303849576
# R2: 0.9039336162776381

# %%
## Cross Validation
from sklearn.linear_model import LinearRegression, Lasso, LassoCV

model_L=LassoCV(cv=5)

model_L.fit(X_train,y_train)

y_pred=model_L.predict(X_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R2: {r2}")

print(f"{model_L.alphas_}")
# Out:
# MAE: 1.0652736863041175
# MSE: 2.655855021618954
# RMSE: 1.6296794229599127
# R2: 0.9590027510893289
# [6.60177147 6.15683417 5.74188415 5.35490038 4.99399801 4.65741926
#  4.34352479 4.05078576 3.77777635 3.52316687 3.28571722 3.06427087
#  2.85774927 2.66514654 2.48552458 2.31800854 2.16178252 2.01608562
#  1.88020819 1.75348845 1.6353092  1.52509483 1.42230855 1.32644971
#  1.23705144 1.15367831 1.07592426 1.00341056 0.93578405 0.87271534
#  0.81389724 0.75904329 0.70788632 0.66017715 0.61568342 0.57418842
#  0.53549004 0.4993998  0.46574193 0.43435248 0.40507858 0.37777764
#  0.35231669 0.32857172 0.30642709 0.28577493 0.26651465 0.24855246
#  0.23180085 0.21617825 0.20160856 0.18802082 0.17534885 0.16353092
#  0.15250948 0.14223085 0.13264497 0.12370514 0.11536783 0.10759243
#  0.10034106 0.0935784  0.08727153 0.08138972 0.07590433 0.07078863
#  0.06601771 0.06156834 0.05741884 0.053549   0.04993998 0.04657419
#  0.04343525 0.04050786 0.03777776 0.03523167 0.03285717 0.03064271
#  0.02857749 0.02665147 0.02485525 0.02318009 0.02161783 0.02016086
#  0.01880208 0.01753488 0.01635309 0.01525095 0.01422309 0.0132645
#  0.01237051 0.01153678 0.01075924 0.01003411 0.00935784 0.00872715
#  0.00813897 0.00759043 0.00707886 0.00660177]

# %%
from sklearn.linear_model import LinearRegression, Ridge

model_r=Ridge()

model_r.fit(X_train,y_train)

y_pred=model_r.predict(X_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R2: {r2}")
# Out:
# MAE: 1.0874050966079847
# MSE: 2.643225847125102
# RMSE: 1.6258000636994396
# R2: 0.9591977020207788

# %%
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV

model_r=RidgeCV(cv=5)

model_r.fit(X_train,y_train)

y_pred=model_r.predict(X_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R2: {r2}")
# Out:
# MAE: 1.0874050966079847
# MSE: 2.643225847125102
# RMSE: 1.6258000636994396
# R2: 0.9591977020207788

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet

model_e=ElasticNet()

model_e.fit(X_train,y_train)

y_pred=model_e.predict(X_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R2: {r2}")
# Out:
# MAE: 2.2674289654428064
# MSE: 10.945206849946057
# RMSE: 3.3083540998427083
# R2: 0.8310437256727631

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, ElasticNetCV

model_e=ElasticNetCV(cv=5)

model_e.fit(X_train,y_train)

y_pred=model_e.predict(X_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R2: {r2}")
# Out:
# MAE: 1.1100730588601033
# MSE: 2.8137988159769742
# RMSE: 1.6774381705377324
# R2: 0.9565646432112699
