# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_moons

X,y=make_moons(n_samples=250,noise=0.05)

# %%
X[:10]
# Out:
# array([[-0.04504672,  0.31764397],
#        [ 0.22586617, -0.13250393],
#        [-0.03875443,  0.42914817],
#        [ 0.10611003,  0.97836941],
#        [ 0.0694309 ,  0.00626493],
#        [ 1.72620246, -0.14197758],
#        [-0.77664811,  0.60692682],
#        [ 0.62612462,  0.78024362],
#        [ 1.14053561, -0.55088826],
#        [ 1.76406998,  0.05121188]])

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
plt.scatter(X_scaled[:,0],X_scaled[:,1],c=y)

# %%
from sklearn.cluster import DBSCAN
model=DBSCAN(eps=0.3)
model.fit(X_scaled)
# Out:
# DBSCAN(eps=0.3)

# %%
plt.scatter(X_scaled[:,0],X_scaled[:,1],c=model.labels_)
